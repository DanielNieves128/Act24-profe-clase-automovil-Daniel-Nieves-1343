# %% [markdown]
# <a href="https://colab.research.google.com/github/DanielNieves128/Act24-profe-clase-automovil-Daniel-Nieves-1343/blob/main/profe_clase_automovil_Daniel_1343.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Daniel Nieves NL = 41 Fecha 29/Abril/2026
#
# ### Clase automovil con 3 atributos funciones leerdatos(), Mostrardatos()
#
# ### que seainteractivo
#
# ### crear 3 objetos Carro1, carro2, carro3
#
# ### No usar while, true, if, for, listas y diccionarios

# %%
  def __init__(self, marca, placa, precio):
    self.marca = marca
    self.placa = placa
    self.precio = precio

  def obtener_datos_automovil(self):
    self.marca = input("ingresa la marca: ")
    self.placa = input("ingrese la placa: ")
    self.precio = input("ingrese el precio: ")
    return self.marca, self.placa, self.precio
    print("-----------------------------------")
  def mostrar_datos_automovil(self):
    print("marca: ", self.marca)
    print("placa: ", self.placa)
    print("precio: ", self.precio)
    return self.marca, self.placa, self.precio
    print("-----------------------------------")

# fin de la clase automovil

# creando los datos para carro1, carro2, carro3
# se deben crear instancias separadas para cada carro
print("carro numero1")
carro1 = Automovil("", "", "")
carro1.obtener_datos_automovil()
carro1.mostrar_datos_automovil()
print("*_*_*_*_*_*_*_*_*_*_*_*_*_*")

print("carro numero2")
carro2 = Automovil("", "", "")
carro2.obtener_datos_automovil()
carro2.mostrar_datos_automovil()
print("*_*_*_*_*_*_*_*_*_*_*_*_*_*")

print("carro numero3")
carro3 = Automovil("", "", "")
carro3.obtener_datos_automovil()
carro3.mostrar_datos_automovil()
print("software desarrollado por Daniel Nieves NL = 41")
# Out:
# carro numero1
# ingresa la marca: NISSAN
# ingrese la placa: SAW 678 N
# ingrese el precio: 90,000
# marca:  NISSAN
# placa:  SAW 678 N
# precio:  90,000
# *_*_*_*_*_*_*_*_*_*_*_*_*_*
# carro numero2
# ingresa la marca: HYUNDAI
# ingrese la placa: 150,000

# %% [markdown]
# ![]()
